# %%
import subprocess
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import pandas
import time

# %%
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [3.659514266,3.715585348,239.4443198,186.1268352,681.7408756,581.6168305] #intercloud

throughput_image = [8.291991495,5.710102489,448.9690579,371.3982437,751.5793289,701.8311429] #intercloud

throughput_video = [492.920354,428.4615385,606.0812095,428.1963893,795.142852,731.3568514] #intercloud

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Throughput (Mbps)',fontsize=20)
plt.tight_layout()
plt.legend(loc='upper left', ncol=1,frameon=False,fontsize=20)
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)
plt.grid(axis = 'y')
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/intercloud_throughput.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/intercloud_throughput.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
### 
#InterCLoud
#Energy
####
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [51369.88183,11268.44051,1845.449893,825.6324814,470.3618264,502.0326951] #intercloud

throughput_image = [14427.08795,8677.733728,7220.519945,3166.509379,2508.967139,2518.373993] #intercloud

throughput_video = [3297.752193,1858.443298,14852.22783,6188.80206,6940.711178,5578.699351] #intercloud

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Energy Consumption(Joules)',fontsize=20)
plt.tight_layout()
plt.legend(loc='upper center',ncol=1, frameon=False,fontsize=20)
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)
plt.yscale('log',base=10)
plt.grid(axis = 'y')
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/intercloud_energy.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/intercloud_energy.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [2.853990438,2.861356932,400.6719422,264.1772294,1219.722853,787.9078129] #Chameleon

throughput_image = [3.700189753,4.367301232,1601.197413,1266.556743,5235.89789,5270.592702] #Chameleon

throughput_video = [547.4201474,335.5421687,2316.647613,2138.205621,5734.315421,5594.114427] #Chameleon

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Throughput (Mbps)',fontsize=20)
plt.tight_layout()
plt.legend(loc='upper left', frameon=False,fontsize=20,ncol=1)
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)
plt.grid(axis = 'y')
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/chameleon_throughput.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/chameleon_throughput.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
### 
#Chameleon
#Energy
####
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [64755.20106,68204.14394,1884.309438,1463.015653,565.2389441,816.2299802] #Chameleon

throughput_image = [162423.2999,139357.1265,3248.655486,2434.145743,1083.146409,1091.585839] #Chameleon

throughput_video = [31122.29063,51192.71765,5196.204786,4000.633417,3651.201338,2376.02487] #Chameleon

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Energy Consumption(Joules)',fontsize=20)
plt.tight_layout()
plt.legend(loc='upper right', frameon=False,fontsize=20,ncol=1)
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)
plt.yscale('log',base=10)
plt.grid(axis = 'y')
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/chameleon_energy.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/chameleon_energy.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [4.211668928,3.230641132,349.5801366,187.2371718,880.7534661,789.0644271] #Cloudlab

throughput_image = [9.527687296,9.709543568,725.1965158,544.9622315,900.45678,889.32356]#Cloudlab

throughput_video = [495.1111111,474.0425532,815.7787534,715.3737689,932.2268497,888.6415873]#Cloudlab

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Throughput (Mbps)',fontsize=20)
plt.tight_layout()
# plt.legend(loc='upper left', frameon=False,fontsize=14)
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)

plt.legend(loc='upper left', frameon=False,ncol=1,fontsize=18)
plt.grid(axis = 'y')
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/cloudlab_throughput.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/cloudlab_throughput.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
### 
#cloudlab
#Energy
####
plt.rcParams["figure.figsize"] = (8,8)
algs = ('      curl','    wget','Max Tput Di-Tacchio','Min Energy Di Tacchio','Max Tput D-Tree','Min Energy D-Tree' )
y_pos = np.arange(len(algs))

print("y_pos = ",y_pos)

throughput_html = [7764.735129,5289.77778,427.5606431,367.2966948,1204.760138,514.0818004] #Cloudlab

throughput_image = [3390.65467,3507.898923,2205.80347,1971.812308,3736.678547,1876.521412]#Cloudlab

throughput_video = [14846.00375,15975.82614,6556.456789,4661.242178,7852.531532,4622.551177]#Cloudlab

#tput_mixed = [

#]

plt.bar(y_pos-0.3, throughput_html, align='center', width=0.2, color='none', edgecolor='red', hatch='xxx', lw=1, zorder=0, label='small files')
plt.bar(y_pos-0.1, throughput_image, align='center', width=0.2, color='none', edgecolor='purple', hatch='---', lw=1, zorder=0, label='medium files')
plt.bar(y_pos+0.1, throughput_video, align='center', width=0.2, color='none', edgecolor='blue', hatch='///', lw=1, zorder=0, label='large files')
#plt.bar(y_pos+0.3, tput_mixed, align='center', width=0.2, color='none', edgecolor='green', hatch='+++', lw=1, zorder=0, label='mixed')

plt.xticks(y_pos+0.2, algs,fontsize=20)
plt.xticks(rotation=50,ha='right', rotation_mode='anchor')
plt.ylabel('Avg. Energy Consumption(Joules)',fontsize=20)
plt.tight_layout()
plt.legend(loc='upper center',ncol=1,frameon=False,fontsize=20,bbox_to_anchor=(.60, 1.05))
# plt.legend(loc='upper center',frameon=False,fontsize=16,bbox_to_anchor=(1.20, 1),
#           ncol=1,fancybox=True, shadow=True)
plt.grid(axis = 'y')
plt.yscale('log',base=10)
#plt.yscale("log")
#plt.title('Chameleon Testbed (Client)')
#plt.savefig('/Users/usr/Downloads/Chameleon_Client_Throughput.pdf', format='pdf', dpi=1000)
plt.savefig('figures/cloudlab_energy.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/cloudlab_energy.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# y_pos =  [0 1 2 3 4 5]
# [8.0, 8.0]

# %%
######
##Block to Plot convergence
########

# %%
import pandas as pd
 

data = [[3600.603126,3760.603126,3219.814916,3653.943561], [6779.422725,	6759.404014,	5129.226448,	4735.362558], [4509.864058,	5402.641594,	6083.74804,	4694.589078], [5158.68341,	 7156.15739,	6572.378877,	5319.563027],[6701.764485,	5757.769421,	6445.957733,	4974.007466],[5693.603066,	5753.898867,	6471.417899,	5314.296574],[5904.741822,	5854.25491,	7185.533547,	5401.063998],[5829.254605,	5753.898867,	6471.417899,	5605.231802]]
 
# Create the pandas DataFrame
data_chameleon = pd.DataFrame(data)

# %%
data_chameleon
# Out:
#              0            1            2            3
# 0  3600.603126  3760.603126  3219.814916  3653.943561
# 1  6779.422725  6759.404014  5129.226448  4735.362558
# 2  4509.864058  5402.641594  6083.748040  4694.589078
# 3  5158.683410  7156.157390  6572.378877  5319.563027
# 4  6701.764485  5757.769421  6445.957733  4974.007466
# 5  5693.603066  5753.898867  6471.417899  5314.296574
# 6  5904.741822  5854.254910  7185.533547  5401.063998
# 7  5829.254605  5753.898867  6471.417899  5605.231802

# %%
means = data_chameleon.mean(axis =1)
x = np.arange(len(means))
means
# Out:
# 0    3558.741182
# 1    5850.853936
# 2    5172.710692
# 3    6051.695676
# 4    5969.874776
# 5    5808.304101
# 6    6086.398569
# 7    5914.950793
# dtype: float64

# %%
fig, ax = plt.subplots()
stdev = data_chameleon.std(axis=1)
ax.errorbar(x, means, yerr=stdev, color='red', ls='--', marker='o', capsize=5, capthick=1, ecolor='black')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.rcParams["figure.figsize"] = (8,8)

# Create the pandas DataFrame
data_chameleon= [[3600.603126,3760.603126,3219.814916,3653.943561], [6779.422725,	6759.404014,	5129.226448,	4735.362558], [4509.864058,	5402.641594,	6083.74804,	4694.589078], [5158.68341,	 7156.15739,	6572.378877,	5319.563027],[6701.764485,	5757.769421,	6445.957733,	4974.007466],[5693.603066,	5753.898867,	6471.417899,	5314.296574],[5904.741822,	5854.25491,	7185.533547,	5401.063998],[5829.254605,	5753.898867,	6471.417899,	5605.231802]]
data_chameleon = pd.DataFrame(data_chameleon)
means_chameleon = data_chameleon.mean(axis =1)
x_chameleon = np.arange(len(means_chameleon)) 
fig, ax = plt.subplots()
stdev_chameleon = data_chameleon.std(axis=1)
# Create the pandas DataFrame
data_intercloud = [[102.4,	102.4,	50.1826472], [559.5974848,	610.7974848,	611.8148376], [699.8617544,	491.8349224,	813.8966888], [719.9295624,	544.856792,	989.1074752],[719.9295624,	544.856792,	989.1074752],[699.9131056,	811.9257264,	811.9257264],[900.9105496,	918.0437352,	989.1074752],[918.0437352,	813.8966888,	811.9257264]]
data_intercloud = pd.DataFrame(data_intercloud)
means_intercloud = data_intercloud.mean(axis =1)
x_intercloud = np.arange(len(means_intercloud))
stdev_intercloud = data_intercloud.std(axis=1)

#####
data_cloudlab=[[549.9739272,	537.1739272],[697.1974848,	668.3974848],[806.4074416,	787.2074416],[849.8230808,	787.2074416],[900.9416264,	843.6716336],[849.8230808,	838.6265216],[714.196428,	714.196428],[849.8230808,	923.7569472]] # ,[777.7065344,	900.9416264],[714.196428,	647.0916648]
data_cloudlab = pd.DataFrame(data_cloudlab)
means_cloudlab = data_cloudlab.mean(axis =1)
x_cloudlab = np.arange(len(means_cloudlab))
stdev_cloudlab = data_cloudlab.std(axis=1)

ax.errorbar(x_cloudlab, means_cloudlab, yerr=stdev_cloudlab, color='black', ls='--', marker='o', capsize=5, capthick=1, ecolor='black',label='cloudlab')
ax.errorbar(x_intercloud, means_intercloud, yerr=stdev_intercloud, color='blue', ls='--', marker='o', capsize=5, capthick=1, ecolor='blue',label='intercloud')
ax.errorbar(x_chameleon, means_chameleon, yerr=stdev_chameleon, color='red', ls='--', marker='o', capsize=5, capthick=1, ecolor='red',label='chameleon')
# plt.xticks(y_pos-0.4, algs,fontsize=16)
# plt.xticks(rotation=50)
plt.yscale('log',base=10)
plt.xlabel('timesteps',fontsize=20)
plt.ylabel('Instanteneous Throughput',fontsize=20)
plt.tight_layout()

plt.legend(loc='lower right',ncol=1,frameon=False,fontsize=20)
plt.savefig('figures/convergence.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('figures/convergence.eps', format='eps', dpi=300, bbox_inches='tight')
plt.show();
print(plt.rcParams.get('figure.figsize'))


plt.show();
# Out:
# [8.0, 8.0]
